# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"D:\Dig\lending_club_new_data.csv")
data.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  annual_inc  \
# 0       5000         5000             4975     10.65       162.87       24000
# 1       2500         2500             2500     15.27        59.83       30000
# 2       2400         2400             2400     15.96        84.33       12252
# 3      10000        10000            10000     13.49       339.31       49200
# 4       5000         5000             5000      7.90       156.46       36000
#
#      dti  delinq_2yrs  inq_last_6mths  open_acc  ...  total_rec_late_fee  \
# 0  27.65            0               1         3  ...                0.00
# 1   1.00            0               5         3  ...                0.00
# 2   8.72            0               2         2  ...                0.00
# 3  20.00            0               1        10  ...               16.97
# 4  11.20            0               3         9  ...                0.00
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516 entries, 0 to 9515
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                9516 non-null   int64
#  1   funded_amnt              9516 non-null   int64
#  2   funded_amnt_inv          9516 non-null   int64
#  3   int_rate                 9516 non-null   float64
#  4   installment              9516 non-null   float64
#  5   annual_inc               9516 non-null   int64
#  6   dti                      9516 non-null   float64
#  7   delinq_2yrs              9516 non-null   int64
#  8   inq_last_6mths           9516 non-null   int64
#  9   open_acc                 9516 non-null   int64
#  10  total_pymnt              9516 non-null   float64
#  11  total_pymnt_inv          9516 non-null   float64
#  12  total_rec_prncp          9516 non-null   float64
#  13  total_rec_int            9516 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# int_rate                   0
# installment                0
# annual_inc                 0
# dti                        0
# delinq_2yrs                0
# inq_last_6mths             0
# open_acc                   0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# total_rec_late_fee         0
# recoveries                 0
# collection_recovery_fee    0
# last_pymnt_amnt            0
# bad_loans                  0
# emp_length_num             0
# grade_num                  0
# sub_grade_num              0
# delinq_2yrs_zero           0
# payment_inc_ratio          0
# dtype: int64

# %%
data['good_loans'] = data['bad_loans'].apply(lambda y:'yes' if y==0 else 'no')

# %%
# Let's Find out the Distribution of Continuous values

for feature in data:
    dataset = data.copy()
    dataset[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
# This will give the correlation between that features

# Example : age in Y-axis and age in X-axis will have the maximum correlation that's why it's dark in color

plt.figure(figsize=(24,20))                                       # Help to set figure size                                     

sns.heatmap(data.corr(),annot=True,cmap='hsv',fmt='.3f',linewidths=2)    
         
# annot : Help to see the value in box
# cmap : The mapping from data values to color space.
# fmt : String formatting code to use when adding annotations.

plt.ylim(35,0)                                                     # show us exact number of values we want
plt.show()

# %%
# corr_matrix = data.corr().abs()
# high_corr_var=np.where(corr_matrix>0.8)
# high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

# %%
corr_matrix = data.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]

# Drop features 
data.drop(to_drop, axis=1, inplace=True)

# %%
# This will give the correlation between that features

# Example : age in Y-axis and age in X-axis will have the maximum correlation that's why it's dark in color

plt.figure(figsize=(24,20))                                       # Help to set figure size                                     

sns.heatmap(data.corr(),annot=True,cmap='hsv',fmt='.3f',linewidths=2)    
         
# annot : Help to see the value in box
# cmap : The mapping from data values to color space.
# fmt : String formatting code to use when adding annotations.

plt.ylim(35,0)                                                     # show us exact number of values we want
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516 entries, 0 to 9515
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                9516 non-null   int64
#  1   int_rate                 9516 non-null   float64
#  2   annual_inc               9516 non-null   int64
#  3   dti                      9516 non-null   float64
#  4   delinq_2yrs              9516 non-null   int64
#  5   inq_last_6mths           9516 non-null   int64
#  6   open_acc                 9516 non-null   int64
#  7   total_rec_int            9516 non-null   float64
#  8   total_rec_late_fee       9516 non-null   float64
#  9   recoveries               9516 non-null   float64
#  10  collection_recovery_fee  9516 non-null   float64
#  11  last_pymnt_amnt          9516 non-null   float64
#  12  bad_loans                9516 non-null   int64
#  13  emp_length_num           9516 non-null   int64
# ...

# %%
# Let's Find out the Distribution of Continuous values

for feature in data:
    dataset = data.copy()
    dataset[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
# # open_acc, total_rec_int, last_pymnt_amnt, payment_inc_ratio, 

# from scipy import stats

# data['boxcox_open_acc'] = stats.boxcox(data['open_acc'])[0]
# pd.Series(boxcox_data).skew()

# , 'total_rec_int_boxcox', 
#       'last_pymnt_amnt_boxcox', 'payment_inc_ratio_boxcox']

# %%
from scipy import stats
data['open_acc_boxcox'], param = stats.boxcox(data['open_acc']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.19441318958776238

# %%
data['total_rec_int_boxcox'], param = stats.boxcox(data['total_rec_int']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.17380799429094132

# %%
data['last_pymnt_amnt_boxcox'], param = stats.boxcox(data['last_pymnt_amnt']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.06866495733226258

# %%
data['payment_inc_ratio_boxcox'], param = stats.boxcox(data['payment_inc_ratio']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.31315388107859093

# %%
data['inq_last_6mths_boxcox'], param = stats.boxcox(data['inq_last_6mths']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  -0.6872799114498171

# %%
data['dti_boxcox'], param = stats.boxcox(data['dti']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.8096220752353134

# %%
data['annual_inc_boxcox'], param = stats.boxcox(data['annual_inc']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  -0.07254548631212206

# %%
data['int_rate_boxcox'], param = stats.boxcox(data['int_rate']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.27138166102588496

# %%
data['loan_amnt_boxcox'], param = stats.boxcox(data['loan_amnt']+1)

print('Optimal lambda: ', param)
# Out:
# Optimal lambda:  0.25757636428361214

# %%
# Let's Find out the Distribution of Continuous values

for feature in data:
    dataset = data.copy()
    dataset[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
data.drop(['loan_amnt', 'open_acc', 'total_rec_int', 'last_pymnt_amnt', 'payment_inc_ratio', 'inq_last_6mths', 'dti',
          'annual_inc', 'int_rate'], axis=1)
# Out:
#       delinq_2yrs  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0               0                0.00        0.00                    0.000
# 1               0                0.00      117.08                    1.110
# 2               0                0.00        0.00                    0.000
# 3               0               16.97        0.00                    0.000
# 4               0                0.00        0.00                    0.000
# ...           ...                 ...         ...                      ...
# 9511            1                0.00        0.00                    0.000
# 9512            1                0.00        0.00                    0.000
# 9513            4                0.00     1159.40                   11.594
# 9514            0                0.00        0.00                    0.000
# 9515            3                0.00        0.00                    0.000
#
# ...

# %%
data.head()
# Out:
#    loan_amnt  int_rate  annual_inc    dti  delinq_2yrs  inq_last_6mths  \
# 0       5000     10.65       24000  27.65            0               1
# 1       2500     15.27       30000   1.00            0               5
# 2       2400     15.96       12252   8.72            0               2
# 3      10000     13.49       49200  20.00            0               1
# 4       5000      7.90       36000  11.20            0               3
#
#    open_acc  total_rec_int  total_rec_late_fee  recoveries  ...  good_loans  \
# 0         3         861.07                0.00        0.00  ...         yes
# 1         3         435.17                0.00      117.08  ...          no
# 2         2         603.65                0.00        0.00  ...         yes
# 3        10        2209.33               16.97        0.00  ...         yes
# 4         9         631.38                0.00        0.00  ...         yes
#
#    open_acc_boxcox  total_rec_int_boxcox  last_pymnt_amnt_boxcox  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516 entries, 0 to 9515
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_amnt                 9516 non-null   int64
#  1   int_rate                  9516 non-null   float64
#  2   annual_inc                9516 non-null   int64
#  3   dti                       9516 non-null   float64
#  4   delinq_2yrs               9516 non-null   int64
#  5   inq_last_6mths            9516 non-null   int64
#  6   open_acc                  9516 non-null   int64
#  7   total_rec_int             9516 non-null   float64
#  8   total_rec_late_fee        9516 non-null   float64
#  9   recoveries                9516 non-null   float64
#  10  collection_recovery_fee   9516 non-null   float64
#  11  last_pymnt_amnt           9516 non-null   float64
#  12  bad_loans                 9516 non-null   int64
# ...

# %%
# This will give the correlation between that features

# Example : age in Y-axis and age in X-axis will have the maximum correlation that's why it's dark in color

plt.figure(figsize=(24,20))                                       # Help to set figure size                                     

sns.heatmap(data.corr(),annot=True,cmap='hsv',fmt='.3f',linewidths=2)    
         
# annot : Help to see the value in box
# cmap : The mapping from data values to color space.
# fmt : String formatting code to use when adding annotations.

plt.ylim(35,0)                                                     # show us exact number of values we want
plt.show()

# %%
data.drop(['loan_amnt', 'open_acc', 'total_rec_int', 'last_pymnt_amnt', 'payment_inc_ratio', 'inq_last_6mths', 'dti',
          'annual_inc', 'int_rate'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    delinq_2yrs  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0            0                0.00        0.00                     0.00
# 1            0                0.00      117.08                     1.11
# 2            0                0.00        0.00                     0.00
# 3            0               16.97        0.00                     0.00
# 4            0                0.00        0.00                     0.00
#
#    bad_loans  emp_length_num  sub_grade_num good_loans  open_acc_boxcox  \
# 0          0              11            0.4        yes         1.591085
# 1          1               1            0.8         no         1.591085
# 2          0              11            1.0        yes         1.224754
# 3          0              11            0.2        yes         3.054823
# 4          0               4            0.8        yes         2.904307
#
#    total_rec_int_boxcox  last_pymnt_amnt_boxcox  payment_inc_ratio_boxcox  \
# ...

# %%
# This will give the correlation between that features

# Example : age in Y-axis and age in X-axis will have the maximum correlation that's why it's dark in color

plt.figure(figsize=(24,20))                                       # Help to set figure size                                     

sns.heatmap(data.corr(),annot=True,cmap='hsv',fmt='.3f',linewidths=2)    
         
# annot : Help to see the value in box
# cmap : The mapping from data values to color space.
# fmt : String formatting code to use when adding annotations.

plt.ylim(35,0)                                                     # show us exact number of values we want
plt.show()

# %%
corr_matrix = data.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]

# Drop features 
data.drop(to_drop, axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516 entries, 0 to 9515
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   delinq_2yrs               9516 non-null   int64
#  1   total_rec_late_fee        9516 non-null   float64
#  2   recoveries                9516 non-null   float64
#  3   collection_recovery_fee   9516 non-null   float64
#  4   bad_loans                 9516 non-null   int64
#  5   emp_length_num            9516 non-null   int64
#  6   sub_grade_num             9516 non-null   float64
#  7   good_loans                9516 non-null   object
#  8   open_acc_boxcox           9516 non-null   float64
#  9   total_rec_int_boxcox      9516 non-null   float64
#  10  last_pymnt_amnt_boxcox    9516 non-null   float64
#  11  payment_inc_ratio_boxcox  9516 non-null   float64
#  12  inq_last_6mths_boxcox     9516 non-null   float64
# ...

# %%
# This will give the correlation between that features

# Example : age in Y-axis and age in X-axis will have the maximum correlation that's why it's dark in color

plt.figure(figsize=(24,20))                                       # Help to set figure size                                     

sns.heatmap(data.corr(),annot=True,cmap='hsv',fmt='.3f',linewidths=2)    
         
# annot : Help to see the value in box
# cmap : The mapping from data values to color space.
# fmt : String formatting code to use when adding annotations.

plt.ylim(35,0)                                                     # show us exact number of values we want
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9516 entries, 0 to 9515
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   delinq_2yrs               9516 non-null   int64
#  1   total_rec_late_fee        9516 non-null   float64
#  2   recoveries                9516 non-null   float64
#  3   collection_recovery_fee   9516 non-null   float64
#  4   bad_loans                 9516 non-null   int64
#  5   emp_length_num            9516 non-null   int64
#  6   sub_grade_num             9516 non-null   float64
#  7   good_loans                9516 non-null   object
#  8   open_acc_boxcox           9516 non-null   float64
#  9   total_rec_int_boxcox      9516 non-null   float64
#  10  last_pymnt_amnt_boxcox    9516 non-null   float64
#  11  payment_inc_ratio_boxcox  9516 non-null   float64
#  12  inq_last_6mths_boxcox     9516 non-null   float64
# ...

# %%
data[['good_loans', 'bad_loans']].head()
# Out:
#   good_loans  bad_loans
# 0        yes          0
# 1         no          1
# 2        yes          0
# 3        yes          0
# 4        yes          0

# %%
# good_loans == 0 } bad_loans

data.drop('good_loans',axis=1,inplace=True)

# %%
data.head()
# Out:
#    delinq_2yrs  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0            0                0.00        0.00                     0.00
# 1            0                0.00      117.08                     1.11
# 2            0                0.00        0.00                     0.00
# 3            0               16.97        0.00                     0.00
# 4            0                0.00        0.00                     0.00
#
#    bad_loans  emp_length_num  sub_grade_num  open_acc_boxcox  \
# 0          0              11            0.4         1.591085
# 1          1               1            0.8         1.591085
# 2          0              11            1.0         1.224754
# 3          0              11            0.2         3.054823
# 4          0               4            0.8         2.904307
#
#    total_rec_int_boxcox  last_pymnt_amnt_boxcox  payment_inc_ratio_boxcox  \
# 0             12.873872                6.179676                  3.192526
# ...

# %%
# Correlation

data.corr()['bad_loans'].sort_values().plot(kind='bar')

# %%
X = data.drop('bad_loans',axis=1)
y = data['bad_loans']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
X_train.shape
# Out:
# (7612, 15)

# %%
X_test.shape
# Out:
# (1904, 15)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=500)
print(cross_val_score(model, X, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.9558594889059725

# %%
model.fit(X_train,y_train)

pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1550
#            1       0.95      0.79      0.86       354
#
#     accuracy                           0.95      1904
#    macro avg       0.95      0.89      0.92      1904
# weighted avg       0.95      0.95      0.95      1904

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[1536   14]
#  [  76  278]]
